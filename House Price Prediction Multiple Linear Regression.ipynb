# %%
# importing libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA

# %%
# loading the data set
hh = pd.read_csv('D:\Data set\Housing - Housing.csv')

# %%
# data preprossing and exploraty analysis
# head, tail, info, describe
hh.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
hh.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
hh.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# from above we came to know that avg price is around 4.7667, max price is 1.3300,min price is 1.7500.
# the avg area is 5150.54 max area is 16200 min area is 1650.
# the max bedrooms is 6, min is 1.
# max bathroom is 4 min is 1

# %%
hh.describe(include = 'O')
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
# top freq for the road is yes. for guestroom it is no, for basement is no.

# %%
hh.describe().style.background_gradient(cmap = 'CMRmap')
# Out:
# <style type="text/css">
# #T_59efa_row0_col0, #T_59efa_row0_col1, #T_59efa_row1_col3, #T_59efa_row1_col4, #T_59efa_row1_col5, #T_59efa_row2_col2, #T_59efa_row2_col3, #T_59efa_row2_col4, #T_59efa_row2_col5, #T_59efa_row3_col2, #T_59efa_row3_col3, #T_59efa_row3_col4, #T_59efa_row3_col5, #T_59efa_row4_col2, #T_59efa_row4_col3, #T_59efa_row4_col4, #T_59efa_row4_col5, #T_59efa_row5_col3, #T_59efa_row5_col4, #T_59efa_row5_col5, #T_59efa_row6_col3, #T_59efa_row6_col4, #T_59efa_row6_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_59efa_row0_col2, #T_59efa_row0_col3, #T_59efa_row0_col4, #T_59efa_row0_col5, #T_59efa_row7_col0, #T_59efa_row7_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_59efa_row1_col0 {
#   background-color: #8e3189;
#   color: #f1f1f1;
# }
# #T_59efa_row1_col1 {
#   background-color: #682ba9;
#   color: #f1f1f1;
# }
# ...

# %%
sns.heatmap(hh.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
# checking for the mull values
hh.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Data visualization
plt.bar(hh.area,hh.price)
sns.barplot('area', 'price', data = hh)
# Out:
# <BarContainer object of 545 artists>

# %%
plt.figure(figsize=(20,7))
sns.scatterplot('area', 'price', data = hh)
# Out:
# D:\Software\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
# most of the scatter points are between 2000 to 8000.

# %%
sns.lmplot('area', 'price', data = hh)
# Out:
# D:\Software\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot('parking', 'price', data = hh)
# Out:
# D:\Software\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='parking', ylabel='price'>

# %% [markdown]
# # import model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
hhm = LinearRegression()

# %%
x = hh.drop(['price'], axis = 1)
y = hh['price']

# %%
print(x)
print('-' * 25)
print(y)
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
import category_encoders as ce

# %%
encoder2 = ce.OrdinalEncoder(cols=['mainroad', 'guestroom','basement','hotwaterheating', 'airconditioning','prefarea','furnishingstatus'])
encoder1 = ce.OrdinalEncoder(cols=['bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom','basement','hotwaterheating', 'airconditioning','parking','prefarea','furnishingstatus'])
encoder = ce.OrdinalEncoder(cols=['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom','basement','hotwaterheating', 'airconditioning','parking','prefarea','furnishingstatus'])

# %%
X = encoder.fit_transform(x)
X1 = encoder1.fit_transform(x)
X2 = encoder2.fit_transform(x)

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0       1         1          1        1         1          1         1
# 1       2         1          2        2         1          1         1
# 2       3         2          1        3         1          1         2
# 3       4         1          1        3         1          1         2
# 4       1         1          3        3         1          2         2
# ..    ...       ...        ...      ...       ...        ...       ...
# 540   113         4          3        4         1          1         2
# 541   279         2          3        4         2          1         1
# 542   284         4          3        4         1          1         1
# 543   272         2          3        4         2          1         1
# 544   211         2          3        3         1          1         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
X1
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         1          1        1         1          1         1
# 1    8960         1          2        2         1          1         1
# 2    9960         2          1        3         1          1         2
# 3    7500         1          1        3         1          1         2
# 4    7420         1          3        3         1          2         2
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         4          3        4         1          1         2
# 541  2400         2          3        4         2          1         1
# 542  3620         4          3        4         1          1         1
# 543  2910         2          3        4         2          1         1
# 544  3850         2          3        3         1          1         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
X2
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          1         1
# 1    8960         4          4        4         1          1         1
# 2    9960         3          2        2         1          1         2
# 3    7500         4          2        2         1          1         2
# 4    7420         4          1        2         1          2         2
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          1         2
# 541  2400         3          1        1         2          1         1
# 542  3620         2          1        1         1          1         1
# 543  2910         3          1        1         2          1         1
# 544  3850         3          1        2         1          1         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
hhm.fit(X,y)
# Out:
# LinearRegression()

# %%
hhm.fit(X1,y)
# Out:
# LinearRegression()

# %%
hhm.fit(X2,y)
# Out:
# LinearRegression()

# %%
score = hhm.score(X,y)

# %%
score = hhm.score(X1,y)

# %%
score = hhm.score(X2,y)

# %%
score
# Out:
# 0.680069137617004

# %%
print(score * 100)
# Out:
# 63.15250924732274

# %%
hhm.predict([[4000,2,58,1,5,1,6,7,8,9,1,1]])
# Out:
# D:\Software\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([62923625.52150124])

# %%
hhm.s
